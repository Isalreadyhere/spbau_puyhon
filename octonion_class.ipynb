# %%
from numbers import Number
octonions = ['','i', 'j', 'k', 'l', 'm', 'n', 'o']

i = [[2,4,7],[3,5,6]]
j = [[3,4,5],[1,6,7]]
k = [[1,4,6],[2,5,7]]
l = [[5,6,7],[1,2,3]]
m = [[1,3,7],[4,6,2]]
n = [[1,2,5],[7,4,3]]
o = [[2,3,6],[5,4,1]]
octs = [[],i, j, k, l, m, n, o]

class InCaseOfValueError(ValueError):
    pass

class InCaseOfAmountError(OverflowError):
    pass

class octonion:
    
    def __init__(self, args=[0]):
        
         if isinstance(args, Number):
            self.args = [args]
         elif isinstance(args, list):
            self.args = args.copy()
         elif isinstance(args, octonion):
            self.args = args.coefficients.copy()
         else:
            raise InCaseOfValueError("You are trying to create octonion from " + repr(arg))
         if len(args) > 8:
            raise InCaseOfAmountError("Too mary arguments.")
            
         for t in range(len(args), 8):
            self.args.append(0)
            
    def __str__(self):
        c = ''
        for t in range(8):
            if self.args[t] != 0: 
                c+=str(self.args[t])
                c+=str(octonions[t])
                if t != 7:
                    
                     c+=(' + ')
        if c == '':
            c = '0'
        if c[len(c)-2] == '+':
            c = c[:len(c)-2]
        return(c)
    
    def __add__(self, other):
        new = octonion()
        for t in range(8):
            new.args[t] = self.args[t] + other.args[t]
        return(new)
    
    
    def __sub__(self, other):
        new = octonion()
        for t in range(8):
            new.args[t] = self.args[t] - other.args[t]
        return(new)
    
    def conj(self): #Комплексное сопряжение
        new = octonion()
        new.args[0] = self.args[0]
        for t in range(1,8):
            new.args[t] += -(self.args[t])
        return(new)
    
    def DivByNumb(self, numb):
        new = octonion()
        for t in range(8):
            new.args[t] = (self.args[t])/numb
        return(new)
    
    def __mul__(self, other): 
        new = octonion() 
        for t in range(8):
            new.args[0] += -(self.args[t] * other.args[t])
        for t in range(1, 8):
            for y in range(3):
                new.args[t] += (self.args[octs[t][0][y]] * other.args[octs[t][1][y]]) - (self.args[octs[t][1][y]] * other.args[octs[t][0][y]])
                
        return(new)
    
    def NormSq(self): #возвращае квадрат нормы октониона
        new = octonion() 
        new = self * self.conj()
        return(new.args[0])
    
    def Norm(self): #возвращает норму октониона
        new = octonion() 
        new = pow(self.NormSq(), 0.5)
        return(new)
    
    def Reversed(self):
        new = octonion() 
        new = self.conj().DivByNumb(self.NormSq()) 
        return(new)
    
    def __truediv__(self, other):
        new = octonion() 
        if isinstance(other, Number):
            new.args[0] = self.DivByNumb(other)
        else:
            new = self * other.Reversed()
        return(new)

# %%
o1 = octonion([0,2,35,42,5,1116, 555, 67])
o2 = octonion([1, -45, 0, -5, 8])
o0 = octonion([0])
#print(o1)
print(o1 + o2)
print(o1 - o2)
print(o1 * o2)
print(o1 * o0)
print(o2.conj())
print(o2.NormSq())
print(o2.Norm())
print(o1 / o2)
print(o1 / 10)
# Out:
# 1 + -43i + 35j + 37k + 13l + 1116m + 555n + 67o
# -1 + 47i + 35j + 47k + -3l + 1116m + 555n + 67o
# 260 + -9103i + -6320j + -7353k + -50555l + 3016m + -2285n + -24614o
# 0
# 1 + 45i + 5k + -8l
# 2113
# 45.967379738244816
# -0.12304779933743493 + 4.308092759110269i + 2.9910080454330337j + 3.4798864174159956k + 23.925698059630857l + -1.427354472314245m + 1.08140085186938n + 11.648840511121628o
# 0.2i + 3.5j + 4.2k + 0.5l + 111.6m + 55.5n + 6.7o
